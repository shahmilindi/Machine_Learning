# %% [markdown]
# # Kaggle 2:
# ## Milindi Shah

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#       id  Mean of the integrated profile  \
# 0  16330                      138.835938
# 1   5999                      130.296875
# 2  10228                      127.328125
# 3   2980                      102.453125
# 4   2472                      104.921875
#
#    Standard deviation of the integrated profile  \
# 0                                     45.453922
# 1                                     51.969546
# 2                                     55.471714
# 3                                     44.412987
# 4                                     41.629431
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.096961
# 1                                  -0.005585
# 2                                   0.090976
# 3                                   0.652927
# 4                                   0.189677
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                            0.086516                  3.082776
# ...

# %%
df.isnull().sum()
# Out:
# id                                              0
# Mean of the integrated profile                  0
# Standard deviation of the integrated profile    0
# Excess kurtosis of the integrated profile       0
# Skewness of the integrated profile              0
# Mean of the DM-SNR curve                        0
# Standard deviation of the DM-SNR curve          0
# Excess kurtosis of the DM-SNR curve             0
# Skewness of the DM-SNR curve                    0
# target_class                                    0
# dtype: int64

# %%
df.dtypes
# Out:
# id                                                int64
# Mean of the integrated profile                  float64
# Standard deviation of the integrated profile    float64
# Excess kurtosis of the integrated profile       float64
# Skewness of the integrated profile              float64
# Mean of the DM-SNR curve                        float64
# Standard deviation of the DM-SNR curve          float64
# Excess kurtosis of the DM-SNR curve             float64
# Skewness of the DM-SNR curve                    float64
# target_class                                      int64
# dtype: object

# %%
df.describe()
# Out:
#                  id  Mean of the integrated profile  \
# count  14318.000000                    14318.000000
# mean    8956.893561                      111.100486
# std     5169.820050                       25.733545
# min        0.000000                        6.179688
# 25%     4483.250000                      100.851562
# 50%     8963.000000                      114.960938
# 75%    13444.750000                      127.255859
# max    17897.000000                      192.617188
#
#        Standard deviation of the integrated profile  \
# count                                  14318.000000
# mean                                      46.566641
# std                                        6.851592
# min                                       24.772042
# 25%                                       42.404460
# 50%                                       46.976703
# 75%                                       51.038117
# max                                       91.808628
#
# ...

# %%
a = df.describe()

# %%
q1 = a.iloc[4]
q1
# Out:
# id                                              4483.250000
# Mean of the integrated profile                   100.851562
# Standard deviation of the integrated profile      42.404460
# Excess kurtosis of the integrated profile          0.026375
# Skewness of the integrated profile                -0.188453
# Mean of the DM-SNR curve                           1.918896
# Standard deviation of the DM-SNR curve            14.419402
# Excess kurtosis of the DM-SNR curve                5.786394
# Skewness of the DM-SNR curve                      34.974919
# target_class                                       0.000000
# Name: 25%, dtype: float64

# %%
q3 = a.iloc[6]
q3
# Out:
# id                                              13444.750000
# Mean of the integrated profile                    127.255859
# Standard deviation of the integrated profile       51.038117
# Excess kurtosis of the integrated profile           0.473492
# Skewness of the integrated profile                  0.922093
# Mean of the DM-SNR curve                            5.465510
# Standard deviation of the DM-SNR curve             28.470878
# Excess kurtosis of the DM-SNR curve                10.711443
# Skewness of the DM-SNR curve                      139.520823
# target_class                                        0.000000
# Name: 75%, dtype: float64

# %%
q2 = a.iloc[5]
q2
# Out:
# id                                              8963.000000
# Mean of the integrated profile                   114.960938
# Standard deviation of the integrated profile      46.976703
# Excess kurtosis of the integrated profile          0.224683
# Skewness of the integrated profile                 0.199815
# Mean of the DM-SNR curve                           2.809365
# Standard deviation of the DM-SNR curve            18.463887
# Excess kurtosis of the DM-SNR curve                8.427879
# Skewness of the DM-SNR curve                      83.020982
# target_class                                       0.000000
# Name: 50%, dtype: float64

# %%
iqr = q3 - q1
iqr
# Out:
# id                                              8961.500000
# Mean of the integrated profile                    26.404297
# Standard deviation of the integrated profile       8.633657
# Excess kurtosis of the integrated profile          0.447116
# Skewness of the integrated profile                 1.110547
# Mean of the DM-SNR curve                           3.546614
# Standard deviation of the DM-SNR curve            14.051476
# Excess kurtosis of the DM-SNR curve                4.925048
# Skewness of the DM-SNR curve                     104.545904
# target_class                                       0.000000
# dtype: float64

# %%
chkp = q3 + iqr*1.5
chkp
# Out:
# id                                              26887.000000
# Mean of the integrated profile                    166.862305
# Standard deviation of the integrated profile       63.988601
# Excess kurtosis of the integrated profile           1.144166
# Skewness of the integrated profile                  2.587914
# Mean of the DM-SNR curve                           10.785431
# Standard deviation of the DM-SNR curve             49.548092
# Excess kurtosis of the DM-SNR curve                18.099015
# Skewness of the DM-SNR curve                      296.339679
# target_class                                        0.000000
# dtype: float64

# %%
chkm = q1 - iqr*1.5
chkm
# Out:
# id                                             -8959.000000
# Mean of the integrated profile                    61.245117
# Standard deviation of the integrated profile      29.453975
# Excess kurtosis of the integrated profile         -0.644300
# Skewness of the integrated profile                -1.854273
# Mean of the DM-SNR curve                          -3.401024
# Standard deviation of the DM-SNR curve            -6.657812
# Excess kurtosis of the DM-SNR curve               -1.601178
# Skewness of the DM-SNR curve                    -121.843937
# target_class                                       0.000000
# dtype: float64

# %%
col = df.columns
col
# Out:
# Index(['id', 'Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile',
#        'Skewness of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
sein = df.copy()
sein

for i in col:
    sein[sein[i]<chkm[i]] = 0
    sein[sein[i]>chkp[i]] = 0
    
    
    sein[i]

# %%
col = col[1:-1]
col
# Out:
# Index(['Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile',
#        'Skewness of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve'],
#       dtype='object')

# %%
str_no_outlier = []
for i in col:
    str_no_outlier.append(len(sein[sein['id'] == 0].index))
    
str_no_outlier
# Out:
# [3805, 3805, 3805, 3805, 3805, 3805, 3805, 3805]

# %%
for i in col:
    print(i)
    plt.figure(figsize=(30,30))
    plt.subplot(4, 2, 8)
    fig = df.boxplot(column=i)
    print("\n\n\n")
# Out:
# Mean of the integrated profile
#
#
#
#
# Standard deviation of the integrated profile
#
#
#
#
# Excess kurtosis of the integrated profile
#
#
#
#
# Skewness of the integrated profile
#
#
#
#
# Mean of the DM-SNR curve
#
#
#
#
# Standard deviation of the DM-SNR curve
#
#
#
#
# Excess kurtosis of the DM-SNR curve
#
#
#
#
# Skewness of the DM-SNR curve

# %%
for i in col:
    df[i] = (df[i]-q2[i])/iqr[i]

# %%
df.head()
# Out:
#       id  Mean of the integrated profile  \
# 0  16330                        0.904209
# 1   5999                        0.580812
# 2  10228                        0.468378
# 3   2980                       -0.473704
# 4   2472                       -0.380206
#
#    Standard deviation of the integrated profile  \
# 0                                     -0.176377
# 1                                      0.578300
# 2                                      0.983941
# 3                                     -0.296944
# 4                                     -0.619352
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.719374
# 1                                  -0.515006
# 2                                  -0.299044
# 3                                   0.957789
# 4                                  -0.078293
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.102021                  0.077091
# ...

# %%
df = df.drop(['id'], axis=1)
df.head()
# Out:
#    Mean of the integrated profile  \
# 0                        0.904209
# 1                        0.580812
# 2                        0.468378
# 3                       -0.473704
# 4                       -0.380206
#
#    Standard deviation of the integrated profile  \
# 0                                     -0.176377
# 1                                      0.578300
# 2                                      0.983941
# 3                                     -0.296944
# 4                                     -0.619352
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.719374
# 1                                  -0.515006
# 2                                  -0.299044
# 3                                   0.957789
# 4                                  -0.078293
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.102021                  0.077091
# ...

# %%
corr = df.corr()
corr
# Out:
#                                               Mean of the integrated profile  \
# Mean of the integrated profile                                      1.000000
# Standard deviation of the integrated profile                        0.552478
# Excess kurtosis of the integrated profile                          -0.873473
# Skewness of the integrated profile                                 -0.738974
# Mean of the DM-SNR curve                                           -0.287538
# Standard deviation of the DM-SNR curve                             -0.297747
# Excess kurtosis of the DM-SNR curve                                 0.227218
# Skewness of the DM-SNR curve                                        0.139540
# target_class                                                       -0.672304
#
#                                               Standard deviation of the integrated profile  \
# Mean of the integrated profile                                                    0.552478
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df_t = pd.read_csv('test.csv')
df_t.head()
# Out:
#    id  Mean of the integrated profile  \
# 0  15                      130.960938
# 1  28                       23.703125
# 2  30                      113.882812
# 3  35                      101.882812
# 4  48                       96.335938
#
#    Standard deviation of the integrated profile  \
# 0                                     51.285872
# 1                                     41.677774
# 2                                     45.562907
# 3                                     44.301633
# 4                                     43.957060
#
#    Excess kurtosis of the integrated profile  \
# 0                                   0.072242
# 1                                   4.112599
# 2                                   0.064720
# 3                                   0.584880
# 4                                   0.302221
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.584550                  1.940635
# ...

# %%
df_t.isnull().sum()
# Out:
# id                                              0
# Mean of the integrated profile                  0
# Standard deviation of the integrated profile    0
# Excess kurtosis of the integrated profile       0
# Skewness of the integrated profile              0
# Mean of the DM-SNR curve                        0
# Standard deviation of the DM-SNR curve          0
# Excess kurtosis of the DM-SNR curve             0
# Skewness of the DM-SNR curve                    0
# dtype: int64

# %%
df_t.dtypes
# Out:
# id                                                int64
# Mean of the integrated profile                  float64
# Standard deviation of the integrated profile    float64
# Excess kurtosis of the integrated profile       float64
# Skewness of the integrated profile              float64
# Mean of the DM-SNR curve                        float64
# Standard deviation of the DM-SNR curve          float64
# Excess kurtosis of the DM-SNR curve             float64
# Skewness of the DM-SNR curve                    float64
# dtype: object

# %%
df_t.describe()
# Out:
#                  id  Mean of the integrated profile  \
# count   3580.000000                     3580.000000
# mean    8914.930447                      110.997909
# std     5155.548140                       25.331372
# min       15.000000                        5.812500
# 25%     4418.500000                      101.468750
# 50%     8883.500000                      115.308594
# 75%    13333.000000                      126.517578
# max    17896.000000                      184.296875
#
#        Standard deviation of the integrated profile  \
# count                                   3580.000000
# mean                                      46.481104
# std                                        6.810004
# min                                       24.898211
# 25%                                       42.218766
# 50%                                       46.878067
# 75%                                       50.988776
# max                                       98.778911
#
# ...

# %%
add_ltr = df_t['id']

# %%
df_t = df_t.drop(['id'], axis=1)

# %%
df_t.describe()
# Out:
#        Mean of the integrated profile  \
# count                     3580.000000
# mean                       110.997909
# std                         25.331372
# min                          5.812500
# 25%                        101.468750
# 50%                        115.308594
# 75%                        126.517578
# max                        184.296875
#
#        Standard deviation of the integrated profile  \
# count                                   3580.000000
# mean                                      46.481104
# std                                        6.810004
# min                                       24.898211
# 25%                                       42.218766
# 50%                                       46.878067
# 75%                                       50.988776
# max                                       98.778911
#
#        Excess kurtosis of the integrated profile  \
# count                                3580.000000
# ...

# %%
b = df_t.describe()
q1 = b.iloc[4]
q2 = b.iloc[5]
q3 = b.iloc[6]
col = df_t.columns
iqr = q3-q1
for i in col:
    df_t[i] = (df_t[i]-q2[i])/iqr[i]

# %%
df_t.head()
# Out:
#    Mean of the integrated profile  \
# 0                        0.624873
# 1                       -3.657076
# 2                       -0.056920
# 3                       -0.535984
# 4                       -0.757427
#
#    Standard deviation of the integrated profile  \
# 0                                      0.502600
# 1                                     -0.592963
# 2                                     -0.149961
# 3                                     -0.293778
# 4                                     -0.333068
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.324708
# 1                                   8.787691
# 2                                  -0.341672
# 3                                   0.831469
# 4                                   0.193974
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.684982                 -0.236551
# ...

# %%
Y = df['target_class']

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False
selected_columns = df.columns[columns]
selected_columns = selected_columns[:-1]
df = df[selected_columns]
selected_columns
# Out:
# Index(['Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve'],
#       dtype='object')

# %%
X = df[selected_columns]
X
# Out:
#        Mean of the integrated profile  \
# 0                            0.904209
# 1                            0.580812
# 2                            0.468378
# 3                           -0.473704
# 4                           -0.380206
# ...                               ...
# 14313                        0.076633
# 14314                        0.961018
# 14315                       -0.550337
# 14316                        0.426067
# 14317                        0.675198
#
#        Standard deviation of the integrated profile  \
# 0                                         -0.176377
# 1                                          0.578300
# 2                                          0.983941
# 3                                         -0.296944
# 4                                         -0.619352
# ...                                             ...
# 14313                                      0.959751
# 14314                                      0.315182
# ...

# %%
X_test =   df_t[selected_columns]                
X_test
# Out:
#       Mean of the integrated profile  \
# 0                           0.624873
# 1                          -3.657076
# 2                          -0.056920
# 3                          -0.535984
# 4                          -0.757427
# ...                              ...
# 3575                       -0.638596
# 3576                        1.160078
# 3577                       -2.348382
# 3578                       -0.381910
# 3579                        0.709084
#
#       Standard deviation of the integrated profile  \
# 0                                         0.502600
# 1                                        -0.592963
# 2                                        -0.149961
# 3                                        -0.293778
# 4                                        -0.333068
# ...                                            ...
# 3575                                      0.520313
# 3576                                      1.131419
# ...

# %%
from sklearn.svm import SVC


# import metrics to compute accuracy
from sklearn.metrics import accuracy_score


# instantiate classifier with default hyperparameters
svc=SVC() 


# fit classifier to training set
svc.fit(X,Y)


# make predictions on test set
y_pred = svc.predict(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()
logisticRegr.fit(X, Y)
y_pred2 = logisticRegr.predict(X_test)

# %%
op_data1 = {'id':add_ltr,
        'target_class':y_pred}

op_data2 = {'id':add_ltr,
        'target_class':y_pred2}
 
op1 = pd.DataFrame(op_data1)

op2 = pd.DataFrame(op_data2)

# %%
op1.to_csv('op1.csv',index = False)
op2.to_csv('op2.csv',index = False)
